# %% [markdown]
# <a href="https://colab.research.google.com/github/ThatNinjaGuy/Machine-learning-A-Z-Course/blob/main/web_scraping_valid_url_extractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

def get_urls_to_scrape():
    # Template URL
    template_url = 'https://results.eci.gov.in/PcResultGenJune2024/ConstituencywiseS'

    working_ranges = []

    # Generate URLs for constituencies
    for i in range(4000, 10000):
            url = f'{template_url}{i}.htm'
            if is_url_working(url):
                print(i)
                working_ranges.append((i))
            else:
                print(f'URL {i} is not working')

    return working_ranges

def is_url_working(url):
    # Make a request to the website. Check if the request was successful
    response = requests.get(url)
    return response.status_code == 200

urls = get_urls_to_scrape()
# Out:
# Streaming output truncated to the last 5000 lines.
# URL 5000 is not working
# URL 5001 is not working
# URL 5002 is not working
# URL 5003 is not working
# URL 5004 is not working
# URL 5005 is not working
# URL 5006 is not working
# URL 5007 is not working
# URL 5008 is not working
# URL 5009 is not working
# URL 5010 is not working
# URL 5011 is not working
# URL 5012 is not working
# URL 5013 is not working
# URL 5014 is not working
# URL 5015 is not working
# URL 5016 is not working
# URL 5017 is not working
# URL 5018 is not working
# URL 5019 is not working
# URL 5020 is not working
# URL 5021 is not working
# URL 5022 is not working
# URL 5023 is not working
# URL 5024 is not working
# URL 5025 is not working
# URL 5026 is not working
# URL 5027 is not working
# URL 5028 is not working
# URL 5029 is not working
# URL 5030 is not working
# URL 5031 is not working
# URL 5032 is not working
# URL 5033 is not working
# URL 5034 is not working
# URL 5035 is not working
# ...
